# %% [markdown]
# This notebook preprosses the data by cropping and performing polar transformation

# %%
import hyperspy.api as hs
import numpy as np
import matplotlib.pyplot as plt
import SeqIO

# %%
# %matplotlib notebook

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=4,
                      threads_per_worker=1,
                      dashboard_address=':8704')
client = Client(cluster)

# %%
dc = SeqIO.load_folder('data/',lazy=True,nav_shape=[500,160,160],chunk_shape=[50,8,8])
# Out:
# WARNING:hyperspy.io:`signal_type='Signal2D'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals.

# %%
dc.data
# Out:
# dask.array<get_image_chunk, shape=(500, 160, 160, 128, 256), dtype=float32, chunksize=(50, 8, 8, 128, 256), chunktype=numpy.ndarray>

# %%
dc.set_signal_type('electron_diffraction')
dc.unit = "k_A^-1"
dc.beam_energy=200
dc.diffraction_calibration=0.01239
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl

# %%
dc_slice = dc.isig[60:188,:]/266

# %%
dc_slice.data
# Out:
# dask.array<truediv, shape=(500, 160, 160, 128, 128), dtype=float32, chunksize=(50, 8, 8, 128, 128), chunktype=numpy.ndarray>

# %% [markdown]
# ### Centering the zero beam

# %%
center_list = np.zeros((10,2))
center_list[:,0] = np.linspace(64.2,62.5,10)
center_list[:,1] = np.linspace(62.3,62,10)

# %%
s = np.zeros((500,160,160,2))
for i in range(0,500,50):
    s[i:i+50,:,:] = 64 - center_list[i//50][::-1]

# %%
shifts = hs.signals.Signal1D(s).as_lazy()

# %%
shifts.rechunk(nav_chunks=(50,8,8))

# %%
shifts.data
# Out:
# dask.array<rechunk-merge, shape=(500, 160, 160, 2), dtype=float64, chunksize=(50, 8, 8, 2), chunktype=numpy.ndarray>

# %%
dc_slice.center_direct_beam(shifts=shifts,subpixel=True)

# %%
dc_slice.set_ai()

# %%
dc_slice
# Out:
# /srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/IPython/core/formatters.py:368: FormatterWarning: text/html formatter returned invalid type <class 'pyxem.signals.electron_diffraction2d.LazyElectronDiffraction2D'> (expected <class 'str'>) for object: <LazyElectronDiffraction2D, title: , dimensions: (160, 160, 500|128, 128)>
#   warnings.warn(
# <LazyElectronDiffraction2D, title: , dimensions: (160, 160, 500|128, 128)>

# %% [markdown]
# ### Estimate I(k)

# %%
ik = dc_slice.get_azimuthal_integral1d(npt=64,inplace=False)

# %%
ik.mean().isig[.3:.56].data.shape
# Out:
# (15,)

# %%
ik.mean().plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ik.axes_manager
# Out:
# <Axes manager, axes: (10, 10|64)>
#             Name |   size |  index |  offset |   scale |  units
# ================ | ====== | ====== | ======= | ======= | ======
#             time |     10 |      0 |       0 |       1 | <undefined>
#                y |     10 |      0 |       0 |       1 | <undefined>
# ---------------- | ------ | ------ | ------- | ------- | ------
#           Radius |     64 |      0 |       0 |   0.018 | \AA^{-1}

# %% [markdown]
# ### Polar transformation

# %%
ps = dc_slice.get_azimuthal_integral2d(npt=15,npt_azim=160,radial_range=[.3,.56],inplace=False)
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# WARNING:pyFAI.geometry:No fast path for space: k

# %%
ps.data
# Out:
# dask.array<process_function_blockwise, shape=(500, 160, 160, 15, 160), dtype=float32, chunksize=(50, 8, 8, 15, 160), chunktype=numpy.ndarray>

# %%
ps_slice = ps.inav[80,80,:50]

# %%
ps_slice.compute()

# %%
ps_slice.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
from numcodecs import Blosc

# %%
ps.save('strip_subpix.zspy',compressor=Blosc(shuffle=True,clevel=3))
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# ERROR:hyperspy.io_plugins._hierarchical:The writer could not write the following information in the file: ai : Detector Detector	 Spline= None	 PixelSize= 3.107e-04, 3.107e-04 m
# Wavelength= 2.507934e-12m
# SampleDetDist= 1.000000e+00m	PONI= 1.988691e-02, 1.988691e-02m	rot1=0.000000  rot2= 0.000000  rot3= 0.000000 rad
# DirectBeamDist= 1000.000mm	Center: x=64.000, y=64.000 pix	Tilt=0.000 deg  tiltPlanRotation= 0.000 deg
# Traceback (most recent call last):
#   File "/srv/home/syhuang/hyperspy/hyperspy/io_plugins/_hierarchical.py", line 756, in dict2group
#     group.attrs[key] = value
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/zarr/attrs.py", line 79, in __setitem__
#     self._write_op(self._setitem_nosync, item, value)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/zarr/attrs.py", line 73, in _write_op
#     return f(*args, **kwargs)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/zarr/attrs.py", line 90, in _setitem_nosync
#     self._put_nosync(d)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/zarr/attrs.py", line 112, in _put_nosync
#     self.store[self.key] = json_dumps(d)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/site-packages/zarr/util.py", line 29, in json_dumps
#     return json.dumps(o, indent=4, sort_keys=True, ensure_ascii=True,
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/encoder.py", line 201, in encode
#     chunks = list(chunks)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/encoder.py", line 431, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/encoder.py", line 405, in _iterencode_dict
#     yield from chunks
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/encoder.py", line 438, in _iterencode
#     o = _default(o)
#   File "/srv/home/syhuang/miniconda3/envs/lazy_env/lib/python3.9/json/encoder.py", line 179, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type AzimuthalIntegrator is not JSON serializable
